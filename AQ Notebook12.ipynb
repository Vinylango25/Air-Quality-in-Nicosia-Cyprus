# %%
import pandas as pd
from pandas import MultiIndex, Int16Dtype
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
from platform import python_version
 
 
print("Current Python Version-", python_version())
# Out:
# Current Python Version- 3.8.6

# %%
import numpy
numpy.version.version
# Out:
# '1.23.5'

# %%
import random
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('CO.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO['Ref']=Ref_CO
index_names = Data_CO[ (Data_CO['WE'] >1000)].index
Data_CO.drop(index_names, inplace = True)
WE=Data_CO['WE'].to_list()
AE=Data_CO['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
data = pd.read_csv('Conc_CO.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO.drop(index_names, inplace = True)
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
CO_Data=CO_Data.resample('h').mean()
CO_Data=CO_Data.dropna()
CO_Data.tail()
# Out:
#                            Lab1       Temp         RH         Ref  Net Signal  \
# Date
# 2020-04-30 19:00:00  242.060716  18.870796  71.072939  188.915151   91.471325
# 2020-04-30 20:00:00  218.655079  18.056864  75.132153  178.704750   84.176485
# 2020-04-30 21:00:00  194.147868  17.090891  81.315038  161.421792   73.858294
# 2020-04-30 22:00:00  206.432889  16.714085  82.568155  197.744043   83.279611
# 2020-04-30 23:00:00  173.577429  16.365121  83.662401  162.157636   68.669099
#
#                      Month  Day_of_week   Day  Hour
# Date
# 2020-04-30 19:00:00    4.0          3.0  30.0  19.0
# 2020-04-30 20:00:00    4.0          3.0  30.0  20.0
# 2020-04-30 21:00:00    4.0          3.0  30.0  21.0
# 2020-04-30 22:00:00    4.0          3.0  30.0  22.0
# 2020-04-30 23:00:00    4.0          3.0  30.0  23.0

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna() 
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()

ref_O3=Data_O3['Ref'].to_list()
len(ref_O3)
# Out:
# 60913

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('NO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
Data_NO2['Ref']=Ref_NO2
WE=Data_NO2['WE'].to_list()
AE=Data_NO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
data = pd.read_csv('Conc_NO2.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
subscript = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉") 
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
Data_NO2['Ref_O3']=ref_O3
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
NO2_Data=NO2_Data.resample('h').mean()
NO2_Data=NO2_Data.dropna()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
ref_NO2=Data_NO2['Ref'].to_list()
Data_O3['Ref_NO2']=ref_NO2
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()
# Out:
#                            Lab1       Temp         RH        Ref  Net Signal  \
# Date
# 2019-10-02 11:00:00  621.625704  26.378438  58.063437  46.094860    3.605625
# 2019-10-02 12:00:00  725.154408  25.795055  48.256857  57.532808   13.865109
# 2019-10-07 10:00:00  108.196313  32.344264  37.260757  47.259008   11.447809
# 2019-10-07 11:00:00  135.822676  34.926112  35.013036  42.114260   10.075221
# 2019-10-07 12:00:00  203.757758  36.201221  31.829282  45.701366    7.624153
#
#                      Month  Day_of_week  Day  Hour    Ref_NO2
# Date
# 2019-10-02 11:00:00   10.0          2.0  2.0  11.0  15.230400
# 2019-10-02 12:00:00   10.0          2.0  2.0  12.0   5.384051
# 2019-10-07 10:00:00   10.0          0.0  7.0  10.0   4.255772
# 2019-10-07 11:00:00   10.0          0.0  7.0  11.0  16.268034
# 2019-10-07 12:00:00   10.0          0.0  7.0  12.0  12.770444

# %% [markdown]
# # CO DATA

# %%
from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
from flaml import AutoML
from sklearn.datasets import fetch_california_housing
#'Ref_NO2','Ref_SO2','Ref_O3',
#,'Month','Day_of_week','Day','Hour'

#train_test_split(X, y, test_size = 0.2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/xgboost/compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
from flaml.model import SKLearnEstimator
# SKLearnEstimator is derived from BaseEstimator

# %%
df1=[x for _, x in CO_Data.groupby('Month')]
data_oct=df1[4]
#data_oct=data_oct.sample(frac=1)
data_nov=df1[5]
#data_nov=data_nov.sample(frac=1)
data_dec=df1[6]
#data_dec=data_dec.sample(frac=1)
data_jan=df1[0]
#data_jan=data_jan.sample(frac=1)
data_feb=df1[1]
#data_feb=data_feb.sample(frac=1)
data_mar=df1[2]
#data_mar=data_mar.sample(frac=1)
data_apr=df1[3]
#data_apr=data_apr.sample(frac=1)
data=[data_oct,data_nov,data_dec,data_jan,data_feb,data_mar]

# %%
data_Oct=data_oct.resample('60min').mean()
data_Oct=data_Oct.dropna()
data_Nov=data_nov.resample('60min').mean()
data_Nov=data_Nov.dropna()
data_Dec=data_dec.resample('60min').mean()
data_Dec=data_Dec.dropna()
data_Jan=data_jan.resample('60min').mean()
data_Jan=data_Jan.dropna()
data_Feb=data_feb.resample('60min').mean()
data_Feb=data_Feb.dropna()
data_Mar=data_mar.resample('60min').mean()
data_Mar=data_Mar.dropna()
data_Apr=data_apr.resample('60min').mean()
data_Apr=data_Apr.dropna()

# %%
co_data=CO_Data
co_data=co_data.resample('60min').mean()
co_data=co_data.dropna()
X=co_data[['Net Signal','Temp','RH','Month','Day_of_week','Hour']]
y=co_data['Ref']
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=1)
from flaml import AutoML
from sklearn.datasets import fetch_california_housing

# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 60,  # in seconds
    "metric": 'rmse',
    "eval_method":'holdout',
    "task": 'regression',
    "log_file_name": "california.log",
}

# Train with labeled input data
automl.fit(X_train=X_train, y_train=y_train,
           **automl_settings,estimator_list=["rf"])#,estimator_list=["xgboost"]
pred=automl.predict(X_test)
rmse_r=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y_test),2)
# Out:
# [flaml.automl: 04-23 11:13:48] {2599} INFO - task = regression
# [flaml.automl: 04-23 11:13:48] {2601} INFO - Data split method: uniform
# [flaml.automl: 04-23 11:13:48] {2604} INFO - Evaluation method: holdout
# [flaml.automl: 04-23 11:13:48] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 04-23 11:13:48] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 04-23 11:13:48] {3166} INFO - iteration 0, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:13:48] {3296} INFO - Estimated sufficient time budget=673s. Estimated necessary time budget=1s.
# [flaml.automl: 04-23 11:13:48] {3343} INFO -  at 0.1s,	estimator rf's best error=157.3513,	best estimator rf's best error=157.3513
# [flaml.automl: 04-23 11:13:48] {3166} INFO - iteration 1, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:13:48] {3343} INFO -  at 0.1s,	estimator rf's best error=135.8043,	best estimator rf's best error=135.8043
# [flaml.automl: 04-23 11:13:48] {3166} INFO - iteration 2, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:13:48] {3343} INFO -  at 0.2s,	estimator rf's best error=135.8043,	best estimator rf's best error=135.8043
# [flaml.automl: 04-23 11:13:48] {3166} INFO - iteration 3, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:13:48] {3343} INFO -  at 0.2s,	estimator rf's best error=130.7587,	best estimator rf's best error=130.7587
# [flaml.automl: 04-23 11:13:48] {3166} INFO - iteration 4, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:13:48] {3343} INFO -  at 0.3s,	estimator rf's best error=128.5756,	best estimator rf's best error=128.5756
# [flaml.automl: 04-23 11:13:48] {3166} INFO - iteration 5, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:13
current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:43] {3343} INFO -  at 55.6s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:43] {3166} INFO - iteration 517, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:44] {3343} INFO -  at 55.8s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:44] {3166} INFO - iteration 518, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:44] {3343} INFO -  at 56.1s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:44] {3166} INFO - iteration 519, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:44] {3343} INFO -  at 56.4s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:44] {3166} INFO - iteration 520, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:44] {3343} INFO -  at 56.8s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:44] {3166} INFO - iteration 521, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:45] {3343} INFO -  at 57.1s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:45] {3166} INFO - iteration 522, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:45] {3343} INFO -  at 57.5s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:45] {3166} INFO - iteration 523, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:45] {3343} INFO -  at 57.7s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:45] {3166} INFO - iteration 524, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:46] {3343} INFO -  at 57.9s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:46] {3166} INFO - iteration 525, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:46] {3343} INFO -  at 58.2s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:46] {3166} INFO - iteration 526, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:46] {3343} INFO -  at 58.6s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:46] {3166} INFO - iteration 527, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:46] {3343} INFO -  at 58.8s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:46] {3166} INFO - iteration 528, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:47] {3343} INFO -  at 59.1s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:47] {3166} INFO - iteration 529, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:47] {3343} INFO -  at 59.5s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:47] {3166} INFO - iteration 530, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:48] {3343} INFO -  at 59.8s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:48] {3166} INFO - iteration 531, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:48] {3343} INFO -  at 60.0s,	estimator rf's best error=119.8708,	best estimator rf's best error=119.8708
# [flaml.automl: 04-23 11:14:48] {3602} INFO - retrain rf for 0.3s
# [flaml.automl: 04-23 11:14:48] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.794058201864398, max_leaf_nodes=123,
#                       n_estimators=13, n_jobs=-1)
# [flaml.automl: 04-23 11:14:48] {2901} INFO - fit succeeded
# [flaml.automl: 04-23 11:14:48] {2902} INFO - Time taken to find the best model: 20.42247486114502

# %%
from sklearn.neighbors import LocalOutlierFactor
A=['Net Signal','Temp','RH','Month','Day_of_week','Hour']
B='Ref'
frame1=[data_Oct,data_Nov,data_Dec,data_Jan,data_Feb,data_Mar]#,data_feb
Train1=pd.concat(frame1)
train1=Train1.sample(frac=1)
lof = LocalOutlierFactor()
yhat = lof.fit_predict(train1)
mask = yhat != -1
train1= train1[mask]
test1=data_Apr
yhat = lof.fit_predict(test1)
mask = yhat != -1
test1= test1[mask]

frame2=[data_Oct,data_Nov,data_Dec,data_Jan,data_Feb,data_Apr]#,data_feb
Train2=pd.concat(frame2)
train2=Train2.sample(frac=1)
yhat = lof.fit_predict(train2)
mask = yhat != -1
train2= train2[mask]
test2=data_Mar
yhat = lof.fit_predict(test2)
mask = yhat != -1
test2= test2[mask]

frame3=[data_Oct,data_Nov,data_Dec,data_Jan,data_Mar,data_Apr]#,data_feb
Train3=pd.concat(frame3)
train3=Train3.sample(frac=1)
yhat = lof.fit_predict(train3)
mask = yhat != -1
train3= train3[mask]
test3=data_Feb
yhat = lof.fit_predict(test3)
mask = yhat != -1
test3= test3[mask]

frame4=[data_Oct,data_Nov,data_Dec,data_Feb,data_Mar,data_Apr]#,data_feb
Train4=pd.concat(frame4)
train4=Train4.sample(frac=1)
yhat = lof.fit_predict(train4)
mask = yhat != -1
train4= train4[mask]
test4=data_Jan
yhat = lof.fit_predict(test4)
mask = yhat != -1
test4= test4[mask]

frame5=[data_Oct,data_Nov,data_Jan,data_Feb,data_Mar,data_Apr]#,data_feb
Train5=pd.concat(frame5)
train5=Train5.sample(frac=1)
yhat = lof.fit_predict(train5)
mask = yhat != -1
train5= train5[mask]
test5=data_Dec
yhat = lof.fit_predict(test5)
mask = yhat != -1
test5= test5[mask]

frame6=[data_Oct,data_Dec,data_Jan,data_Feb,data_Mar,data_Apr]#,data_feb
Train6=pd.concat(frame6)
train6=Train6.sample(frac=1)
yhat = lof.fit_predict(train6)
mask = yhat != -1
train6= train6[mask]
test6=data_Nov
yhat = lof.fit_predict(test6)
mask = yhat != -1
test6= test6[mask]

frame7=[data_Nov,data_Dec,data_Jan,data_Feb,data_Mar,data_Apr]#,data_feb
Train7=pd.concat(frame7)
train7=Train7.sample(frac=1)
yhat = lof.fit_predict(train7)
mask = yhat != -1
train7= train7[mask]
test7=data_Oct
yhat = lof.fit_predict(test7)
mask = yhat != -1
test7= test7[mask]


Train=[train1,train2,train3,train4,train5,train6,train7]
Test=[test1,test2,test3,test4,test5,test6,test7]

# %%
from flaml import AutoML
from sklearn.datasets import fetch_california_housing

# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 300,  # in seconds
    "metric": 'rmse',
    "eval_method":'holdout',
    "task": 'regression',
    "log_file_name": "california.log",
}

rmse=[]

# Train with labeled input data
for i in range(7):
    automl.fit(X_train=Train[i][A], y_train=Train[i][B],
           **automl_settings,estimator_list=["rf"])#,estimator_list=["xgboost"]
    pred=automl.predict(Test[i][A])
    R2=round(sm.r2_score(Test[i][B], pred), 2)
    r=round(np.corrcoef(Test[i][B], pred)[0, 1],2)
    RMSE=round(np.sqrt(sm.mean_squared_error(Test[i][B], pred))/np.mean(Test[i][B]),2)
    rmse.append(RMSE)
    print(r,R2,RMSE)
# Predict
#print(automl.predict(X_test))
# Print the best model
#print(automl.model.estimator)
# Out:
# [flaml.automl: 04-23 11:14:50] {2599} INFO - task = regression
# [flaml.automl: 04-23 11:14:50] {2601} INFO - Data split method: uniform
# [flaml.automl: 04-23 11:14:50] {2604} INFO - Evaluation method: holdout
# [flaml.automl: 04-23 11:14:50] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 04-23 11:14:50] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 04-23 11:14:50] {3166} INFO - iteration 0, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:50] {3296} INFO - Estimated sufficient time budget=2059s. Estimated necessary time budget=2s.
# [flaml.automl: 04-23 11:14:50] {3343} INFO -  at 0.5s,	estimator rf's best error=141.2826,	best estimator rf's best error=141.2826
# [flaml.automl: 04-23 11:14:50] {3166} INFO - iteration 1, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:50] {3343} INFO -  at 0.7s,	estimator rf's best error=116.4705,	best estimator rf's best error=116.4705
# [flaml.automl: 04-23 11:14:50] {3166} INFO - iteration 2, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:50] {3343} INFO -  at 0.9s,	estimator rf's best error=116.4705,	best estimator rf's best error=116.4705
# [flaml.automl: 04-23 11:14:50] {3166} INFO - iteration 3, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:51] {3343} INFO -  at 1.3s,	estimator rf's best error=103.8984,	best estimator rf's best error=103.8984
# [flaml.automl: 04-23 11:14:51] {3166} INFO - iteration 4, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14:51] {3343} INFO -  at 1.6s,	estimator rf's best error=103.8984,	best estimator rf's best error=103.8984
# [flaml.automl: 04-23 11:14:51] {3166} INFO - iteration 5, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:14
,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:07] {3166} INFO - iteration 1141, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.0s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1142, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.1s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1143, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.1s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1144, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.2s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1145, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.3s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1146, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.3s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1147, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.4s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1148, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.5s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1149, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.6s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1150, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.6s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1151, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.7s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1152, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.8s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1153, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.8s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1154, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:08] {3343} INFO -  at 77.9s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:08] {3166} INFO - iteration 1155, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:09] {3343} INFO -  at 78.1s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:09] {3166} INFO - iteration 1156, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:09] {3343} INFO -  at 78.1s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:09] {3166} INFO - iteration 1157, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:09] {3343} INFO -  at 78.2s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:09] {3166} INFO - iteration 1158, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]
# [flaml.automl: 04-23 11:46:09] {3343} INFO -  at 78.3s,	estimator rf's best error=105.3588,	best estimator rf's best error=105.3588
# [flaml.automl: 04-23 11:46:09] {3166} INFO - iteration 1159, current learner rf
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/flaml/automl.py:294: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   sampled_y_train = self.y_train[:sample_size]

# %%
import matplotlib.pyplot as plt
import numpy as np
fig= plt.figure(figsize=(5.3,3.5))
ax = fig.add_axes([0,0,1,1])
x= ['Pred1', 'Pred2', 'Pred3','Pred4','Pred5','Pred6','Pred7']
students1=rmse
students2= [48,32,22,18,16]
plt.hlines([rmse_r], -0.5, 6.8, color='orange', linewidth=2)
x = np.arange(7)
wid= 0.7
graph1=ax.bar(x,students1,wid, color='#00BFFF', alpha=1)
#graph2=ax.bar(x+0.2,students2,wid, color='#00BFFF', alpha=1)
#plt.legend(['15min','60min'],title='Data resolution')
i= 0
for p in graph1:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x+width/2,
             y+height+0.02,
             str(students1[i]),
             ha='center',
             weight='bold',fontsize=10, color='#00BFFF', alpha=1)
    i+=1

ax.set_xticks([0,1,2,3,4,5,6])
ax.set_xticklabels(['Pred1', 'Pred2', 'Pred3','Pred4','Pred5','Pred6','Pred7'])
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yticks(np.arange(0,0.7, step=0.1))

#plt.xlabel('Tolerance,Tc (%)', fontsize=19)
plt.ylabel('NRMSE', fontsize=19)
plt.setp(ax.spines.values(), linewidth=1.4)
plt.title("CO-FLAML-RF",fontsize=18)
plt.savefig("Pred_CO_FLAML_RF.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# X=CO_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour']]
# y=CO_Data['Ref']
# X_train, X_test, y_train, y_test =train_test_split(X,y,test_size = 0.2,shuffle=True)
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 1440,  # in seconds
#     "metric": 'rmse',
#     "eval_method":'holdout',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
#
# Pred=[]
# rmse=[]
# model=[]
# RS=[]
# R=[]
# for i in range(10):
#     X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
#     # Train with labeled input data
#     automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["rf"])
#     pred=automl.predict(X_test.drop(['Lab1'], axis=1))
#     R2=round(sm.r2_score(y_test, pred), 2)
#     r=round(np.corrcoef(y_test, pred)[0, 1],2)
#     RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
#     #print(r,R2,RMSE)
#     # Predict
#     #print(automl.predict(X_test))
#     # Print the best model
#     #print(automl.model.estimator)
#     Pred.append(pred)
#     rmse.append(RMSE)
#     model.append(automl.model.estimator)
#     RS.append(R2)
#     R.append(r)
#
# print(np.round(np.mean(R),2),np.round(np.mean(RS),2),np.round(np.mean(rmse),2))

# %%
print(np.round(np.mean(R),2),np.round(np.mean(RS),2),np.round(np.mean(rmse),2))

# %% [markdown]
# Pred=[]
# rmse=[]
# model=[]
# for i in range(20):
#     X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
#     # Train with labeled input data
#     automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["xgboost"])
#     pred=automl.predict(X_test.drop(['Lab1'], axis=1))
#     R2=round(sm.r2_score(y_test, pred), 2)
#     r=round(np.corrcoef(y_test, pred)[0, 1],2)
#     RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
#     print(r,R2,RMSE)
#     # Predict
#     #print(automl.predict(X_test))
#     # Print the best model
#     print(automl.model.estimator)
#     Pred.append(pred)
#     rmse.append(RMSE)
#     model.append(automl.model.estimator)
#
# Sorted_pred=[]
# sort_index = np.argsort(rmse)
# for i in sort_index:
#     Sorted_pred.append(Pred[i])
# ind=[i for i in range(len(y_test))]
# import matplotlib.pyplot as plt
# fig= plt.figure(figsize=(7,5))
# plt.plot(ind[:200],y_test[:200], color='blue',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[1][:200],color='salmon',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[17][:200],color='teal',linewidth=1.5)
# plt.legend(['Actual','p10','p90'],loc = 2, bbox_to_anchor = (0.75,1), fontsize=12)
# #plt.plot(ind[:200],Sorted_pred[4][:200],color='black',linewidth=0.2)
# #plt.fill_between(np.array(ind[:200]), np.array(Sorted_pred[0][:200]), np.array(Sorted_pred[4][:200]),
#                  #color='blue', alpha=0.15)
# #plt.plot(ind,Pred[2],color='darkgoldenrod')
# #plt.plot(ind,Pred[3],color='magenta')
# #plt.plot(ind,Pred[4],color='purple')
# plt.xlabel('Observation number',fontsize=16)
# plt.ylabel('Concentraton (ppb)',fontsize=16)
# plt.title('CO-XGBoost',fontsize=16)
# plt.savefig("co_xgboost.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# Pred=[]
# rmse=[]
# model=[]
# for i in range(20):
#     X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
#     # Train with labeled input data
#     automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["xgb_limitdepth"])
#     pred=automl.predict(X_test.drop(['Lab1'], axis=1))
#     R2=round(sm.r2_score(y_test, pred), 2)
#     r=round(np.corrcoef(y_test, pred)[0, 1],2)
#     RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
#     print(r,R2,RMSE)
#     # Predict
#     #print(automl.predict(X_test))
#     # Print the best model
#     print(automl.model.estimator)
#     Pred.append(pred)
#     rmse.append(RMSE)
#     model.append(automl.model.estimator)
#
# Sorted_pred=[]
# sort_index = np.argsort(rmse)
# for i in sort_index:
#     Sorted_pred.append(Pred[i])
# ind=[i for i in range(len(y_test))]
# import matplotlib.pyplot as plt
# fig= plt.figure(figsize=(7,5))
# plt.plot(ind[:200],y_test[:200], color='blue',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[1][:200],color='salmon',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[17][:200],color='teal',linewidth=1.5)
# plt.legend(['Actual','p10','p90'],loc = 2, bbox_to_anchor = (0.75,1), fontsize=12)
# #plt.plot(ind[:200],Sorted_pred[4][:200],color='black',linewidth=0.2)
# #plt.fill_between(np.array(ind[:200]), np.array(Sorted_pred[0][:200]), np.array(Sorted_pred[4][:200]),
#                  #color='blue', alpha=0.15)
# #plt.plot(ind,Pred[2],color='darkgoldenrod')
# #plt.plot(ind,Pred[3],color='magenta')
# #plt.plot(ind,Pred[4],color='purple')
# plt.xlabel('Observation number',fontsize=16)
# plt.ylabel('Concentraton (ppb)',fontsize=16)
# plt.title('CO-CO-LDXGBooost',fontsize=16)
# plt.savefig("co_ldxgboost.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# Sorted_pred=[]
# sort_index = np.argsort(rmse)
# for i in sort_index:
#     Sorted_pred.append(Pred[i])
# ind=[i for i in range(len(y_test))]
# import matplotlib.pyplot as plt
# fig= plt.figure(figsize=(7,5))
# plt.plot(ind[:200],y_test[:200], color='blue',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[1][:200],color='salmon',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[17][:200],color='teal',linewidth=1.5)
# plt.legend(['Actual','p10','p90'],loc = 2, bbox_to_anchor = (0.75,1), fontsize=12)
# #plt.plot(ind[:200],Sorted_pred[4][:200],color='black',linewidth=0.2)
# #plt.fill_between(np.array(ind[:200]), np.array(Sorted_pred[0][:200]), np.array(Sorted_pred[4][:200]),
#                  #color='blue', alpha=0.15)
# #plt.plot(ind,Pred[2],color='darkgoldenrod')
# #plt.plot(ind,Pred[3],color='magenta')
# #plt.plot(ind,Pred[4],color='purple')
# plt.xlabel('Observation number',fontsize=16)
# plt.ylabel('Concentraton (ppb)',fontsize=16)
# plt.title('CO-LDXGBooost',fontsize=16)
# plt.savefig("co_ldxgboost.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# Pred=[]
# rmse=[]
# model=[]
# for i in range(20):
#     X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
#     # Train with labeled input data
#     automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["extra_tree"])
#     pred=automl.predict(X_test.drop(['Lab1'], axis=1))
#     R2=round(sm.r2_score(y_test, pred), 2)
#     r=round(np.corrcoef(y_test, pred)[0, 1],2)
#     RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
#     print(r,R2,RMSE)
#     # Predict
#     #print(automl.predict(X_test))
#     # Print the best model
#     print(automl.model.estimator)
#     Pred.append(pred)
#     rmse.append(RMSE)
#     model.append(automl.model.estimator)
#
# Sorted_pred=[]
# sort_index = np.argsort(rmse)
# for i in sort_index:
#     Sorted_pred.append(Pred[i])
# ind=[i for i in range(len(y_test))]
# import matplotlib.pyplot as plt
# fig= plt.figure(figsize=(7,5))
# plt.plot(ind[:200],y_test[:200], color='blue',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[1][:200],color='salmon',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[17][:200],color='teal',linewidth=1.5)
# plt.legend(['Actual','p10','p90'],loc = 2, bbox_to_anchor = (0.75,1), fontsize=12)
# #plt.plot(ind[:200],Sorted_pred[4][:200],color='black',linewidth=0.2)
# #plt.fill_between(np.array(ind[:200]), np.array(Sorted_pred[0][:200]), np.array(Sorted_pred[4][:200]),
#                  #color='blue', alpha=0.15)
# #plt.plot(ind,Pred[2],color='darkgoldenrod')
# #plt.plot(ind,Pred[3],color='magenta')
# #plt.plot(ind,Pred[4],color='purple')
# plt.xlabel('Observation number',fontsize=16)
# plt.ylabel('Concentraton (ppb)',fontsize=16)
# plt.title('CO-Extra Tree',fontsize=16)
# plt.savefig("co_extra_tree.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# from flaml.model import SKLearnEstimator

# %% [markdown]
# from flaml.model import SKLearnEstimator
# # SKLearnEstimator is derived from BaseEstimator
# import numpy as np
#
# class RandomForestRegressor(SKLearnEstimator):
#     def __init__(self, task="binary", **config):
#         super().__init__(task, **config)
#
#         if task in CLASSIFICATION:
#             from sklearn.ensemble import RandomForestClassifier
#
#             self.estimator_class =RandomForestClassifier
#         else:
#             from sklearn.ensemble import RandomForestRegressor
#
#             self.estimator_class =RandomForestRegressor
#
#     @classmethod
#     def search_space(cls, data_size, task):
#         space = {
#             "n_estimators": {
#                 "domain": {"domain": tune.loguniform(lower=100, upper=20000)},
#                 "low_cost_init_value": 100,
#             },
#             "max_features": {
#                 "domain": tune.loguniform(lower=0.1, upper=1),
#                 "low_cost_init_value": 0.1,
#             },
#             "max_leaf_nodes": {
#                 "domain": tune.lograndint(lower=100, upper=2500),
#                 "low_cost_init_value": 100,},
#             "min_samples_split": {"domain": tune.lograndint(lower=1, upper=20),
#             "init_value": 20,},
#
#             "min_samples_leaf": {
#                 "domain": tune.lograndint(lower=1, upper=20),
#                 "init_value": 20,
#             },
#         }
#         return space

# %% [markdown]
# from flaml import AutoML
# from flaml import tune
# automl = AutoML()
# automl.add_learner("rfr",RandomForestRegressor )

# %% [markdown]
# automl_settings = {
#     "time_budget": 1000,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["rfr"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)

# %% [markdown]
# #  NO2 DATA

# %% [markdown]
# X=NO2_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_O3']]#'Ref_O3'
# y=NO2_Data['Ref']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# #len(X_test)
# X.shape

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # O3 DATA

# %% [markdown]
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_absolute_error as mae
# import sklearn.metrics as sm
# import matplotlib.pyplot as plt
# #,'Ref_CO','Ref_NO2','Ref_SO2'
# X=O3_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_NO2']]#,'Ref_NO2'
# y=O3_Data['Ref']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# len(X)

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# # SO2 DATA

# %%
import pandas as pd
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('Conc_SO2.txt', header = None,low_memory=False)
data.columns=['Lab2','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_so2=data
#signal=np.array(WE)-np.array(AE)
#Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data=SO2_Data.resample('5min').mean()
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna() 
data = pd.read_csv('SO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_SO2['Ref']=Ref_SO2
WE=Data_SO2['WE'].to_list()
AE=Data_SO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_SO2['Lab2']=Data_so2['Lab2'].to_list()
Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data.shape

# %%
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna()
SO2_Data=SO2_Data.resample('h').mean()
SO2_Data=SO2_Data.dropna()
SO2_Data.head()

# %% [markdown]
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_absolute_error as mae
# import sklearn.metrics as sm
# import matplotlib.pyplot as plt
# #'Ref_CO','Ref_NO2','Ref_O3',
# X=SO2_Data[['Net Signal','Lab2','Temp','RH','Month','Day_of_week','Hour']]
# y=SO2_Data['Ref']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# len(X)

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab2'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab2'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab2'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %%
import pandas as pd
from pandas import MultiIndex, Int16Dtype
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import random
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('CO.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO['Ref']=Ref_CO
index_names = Data_CO[ (Data_CO['WE'] >1000)].index
Data_CO.drop(index_names, inplace = True)
WE=Data_CO['WE'].to_list()
AE=Data_CO['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
data = pd.read_csv('Conc_CO.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_CO=data
Data_CO.drop(index_names, inplace = True)
signal=np.array(WE)-np.array(AE)
Data_CO['Net Signal']=signal
Data_CO['Month']=Data_CO.index.month
Data_CO['Day_of_week']=Data_CO.index.dayofweek
Data_CO['Day']=Data_CO.index.day
Data_CO['Hour']=Data_CO.index.hour
CO_Data=Data_CO
CO_Data=CO_Data[(CO_Data[CO_Data.columns] >= 0).all(axis=1)]
CO_Data=CO_Data.dropna()
CO_Data=CO_Data.resample('h').mean()
CO_Data=CO_Data.dropna()
CO_Data.tail()
# Out:
#                            Lab1       Temp         RH         Ref  Net Signal  \
# Date
# 2020-04-30 19:00:00  242.060716  18.870796  71.072939  188.915151   91.471325
# 2020-04-30 20:00:00  218.655079  18.056864  75.132153  178.704750   84.176485
# 2020-04-30 21:00:00  194.147868  17.090891  81.315038  161.421792   73.858294
# 2020-04-30 22:00:00  206.432889  16.714085  82.568155  197.744043   83.279611
# 2020-04-30 23:00:00  173.577429  16.365121  83.662401  162.157636   68.669099
#
#                      Month  Day_of_week   Day  Hour
# Date
# 2020-04-30 19:00:00    4.0          3.0  30.0  19.0
# 2020-04-30 20:00:00    4.0          3.0  30.0  20.0
# 2020-04-30 21:00:00    4.0          3.0  30.0  21.0
# 2020-04-30 22:00:00    4.0          3.0  30.0  22.0
# 2020-04-30 23:00:00    4.0          3.0  30.0  23.0

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna() 
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()

ref_O3=Data_O3['Ref'].to_list()
len(ref_O3)
# Out:
# 60913

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('NO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
Data_NO2['Ref']=Ref_NO2
WE=Data_NO2['WE'].to_list()
AE=Data_NO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
data = pd.read_csv('Conc_NO2.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
subscript = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉") 
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_NO2=data
signal=np.array(WE)-np.array(AE)
Data_NO2['Net Signal']=signal
Data_NO2['Month']=Data_NO2.index.month
Data_NO2['Day_of_week']=Data_NO2.index.dayofweek
Data_NO2['Day']=Data_NO2.index.day
Data_NO2['Hour']=Data_NO2.index.hour
Data_NO2['Ref_O3']=ref_O3
NO2_Data=Data_NO2
NO2_Data=NO2_Data[(NO2_Data[NO2_Data.columns] >= 0).all(axis=1)]
NO2_Data=NO2_Data.dropna()
NO2_Data=NO2_Data.resample('h').mean()
NO2_Data=NO2_Data.dropna()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('O3.txt', header = None,low_memory=False)
data.columns=['AE','WE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
Data_O3['Ref']=Ref_O3
WE=Data_O3['WE'].to_list()
AE=Data_O3['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
data = pd.read_csv('Conc_O3.txt', header = None,low_memory=False)
data.columns=['Lab1','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_O3=data
signal=np.array(WE)-np.array(AE)
Data_O3['Net Signal']=signal
Data_O3['Month']=Data_O3.index.month
Data_O3['Day_of_week']=Data_O3.index.dayofweek
Data_O3['Day']=Data_O3.index.day
Data_O3['Hour']=Data_O3.index.hour
ref_NO2=Data_NO2['Ref'].to_list()
Data_O3['Ref_NO2']=ref_NO2
O3_Data=Data_O3
O3_Data=O3_Data[(O3_Data[O3_Data.columns] >= 0).all(axis=1)]
O3_Data=O3_Data.dropna()
O3_Data=O3_Data.resample('h').mean()
O3_Data=O3_Data.dropna()
O3_Data.head()
# Out:
#                            Lab1       Temp         RH        Ref  Net Signal  \
# Date
# 2019-10-02 11:00:00  621.625704  26.378438  58.063437  46.094860    3.605625
# 2019-10-02 12:00:00  725.154408  25.795055  48.256857  57.532808   13.865109
# 2019-10-07 10:00:00  108.196313  32.344264  37.260757  47.259008   11.447809
# 2019-10-07 11:00:00  135.822676  34.926112  35.013036  42.114260   10.075221
# 2019-10-07 12:00:00  203.757758  36.201221  31.829282  45.701366    7.624153
#
#                      Month  Day_of_week  Day  Hour    Ref_NO2
# Date
# 2019-10-02 11:00:00   10.0          2.0  2.0  11.0  15.230400
# 2019-10-02 12:00:00   10.0          2.0  2.0  12.0   5.384051
# 2019-10-07 10:00:00   10.0          0.0  7.0  10.0   4.255772
# 2019-10-07 11:00:00   10.0          0.0  7.0  11.0  16.268034
# 2019-10-07 12:00:00   10.0          0.0  7.0  12.0  12.770444

# %% [markdown]
# # CO DATA

# %%
from sktime.performance_metrics.forecasting import sMAPE, smape_loss
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
from flaml import AutoML
from sklearn.datasets import fetch_california_housing
#'Ref_NO2','Ref_SO2','Ref_O3',
#,'Month','Day_of_week','Day','Hour'
X=CO_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour']]
y=CO_Data['Ref']
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size = 0.2,shuffle=True)
#train_test_split(X, y, test_size = 0.2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/xgboost/compat.py:93: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 1440,  # in seconds
    "metric": 'rmse',
    "task": 'regression',
    "log_file_name": "california.log",
}

Pred=[]
rmse=[]
model=[]
RS=[]
R=[]
for i in range(10):
    X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
    # Train with labeled input data
    automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["rf"])
    pred=automl.predict(X_test.drop(['Lab1'], axis=1))
    R2=round(sm.r2_score(y_test, pred), 2)
    r=round(np.corrcoef(y_test, pred)[0, 1],2)
    RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
    #print(r,R2,RMSE)
    # Predict
    #print(automl.predict(X_test))
    # Print the best model
    #print(automl.model.estimator)
    Pred.append(pred)
    rmse.append(RMSE)
    model.append(automl.model.estimator)
    RS.append(R2)
    R.append(r)

print(np.round(np.mean(R),2),np.round(np.mean(RS),2),np.round(np.mean(rmse),2))
# Out:
# [flaml.automl: 12-15 00:33:49] {2599} INFO - task = regression
# [flaml.automl: 12-15 00:33:49] {2601} INFO - Data split method: uniform
# [flaml.automl: 12-15 00:33:49] {2604} INFO - Evaluation method: cv
# [flaml.automl: 12-15 00:33:49] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 12-15 00:33:49] {2870} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl: 12-15 00:33:49] {3166} INFO - iteration 0, current learner rf
# [flaml.automl: 12-15 00:33:50] {3296} INFO - Estimated sufficient time budget=11522s. Estimated necessary time budget=12s.
# [flaml.automl: 12-15 00:33:50] {3343} INFO -  at 1.5s,	estimator rf's best error=165.4297,	best estimator rf's best error=165.4297
# [flaml.automl: 12-15 00:33:50] {3166} INFO - iteration 1, current learner rf
# [flaml.automl: 12-15 00:33:51] {3343} INFO -  at 2.6s,	estimator rf's best error=150.6053,	best estimator rf's best error=150.6053
# [flaml.automl: 12-15 00:33:51] {3166} INFO - iteration 2, current learner rf
# [flaml.automl: 12-15 00:33:52] {3343} INFO -  at 3.6s,	estimator rf's best error=150.6053,	best estimator rf's best error=150.6053
# [flaml.automl: 12-15 00:33:52] {3166} INFO - iteration 3, current learner rf
# [flaml.automl: 12-15 00:33:54] {3343} INFO -  at 4.9s,	estimator rf's best error=141.9314,	best estimator rf's best error=141.9314
# [flaml.automl: 12-15 00:33:54] {3166} INFO - iteration 4, current learner rf
# [flaml.automl: 12-15 00:33:55] {3343} INFO -  at 6.6s,	estimator rf's best error=139.5006,	best estimator rf's best error=139.5006
# [flaml.automl: 12-15 00:33:55] {3166} INFO - iteration 5, current learner rf
# [flaml.automl: 12-15 00:33:57] {3343} INFO -  at 7.8s,	estimator rf's best error=139.5006,	best estimator rf's best error=139.5006
# [flaml.automl: 12-15 00:33:57] {3166} INFO - iteration 6, current learner rf
# [flaml.automl: 12-15 00:33:58] {3343} INFO -  at 8.9s,	estimator rf's best error=136.0077,	best estimator rf's best error=136.0077
# [flaml.automl: 12-15 00:33:58] {3166} INFO - iteration 7, current learner rf
# [flaml.automl: 12-15 00:33:59] {3343} INFO -  at 10.6s,	estimator rf's best error=136.0077,	best estimator rf's best error=136.0077
# [flaml.automl: 12-15 00:33:59] {3166} INFO - iteration 8, current learner rf
# [flaml.automl: 12-15 00:34:01] {3343} INFO -  at 11.9s,	estimator rf's best error=129.7791,	best estimator rf's best error=129.7791
# [flaml.automl: 12-15 00:34:01] {3166} INFO - iteration 9, current learner rf
# [flaml.automl: 12-15 00:34:02] {3343} INFO -  at 13.2s,	estimator rf's best error=129.7791,	best estimator rf's best error=129.7791
# [flaml.automl: 12-15 00:34:02] {3166} INFO - iteration 10, current learner rf
# [flaml.automl: 12-15 00:34:03] {3343} INFO -  at 14.3s,	estimator rf's best error=129.7791,	best estimator rf's best error=129.7791
# [flaml.automl: 12-15 00:34:03] {3166} INFO - iteration 11, current learner rf
# [flaml.automl: 12-15 00:34:06] {3343} INFO -  at 17.1s,	estimator rf's best error=127.0288,	best estimator rf's best error=127.0288
# [flaml.automl: 12-15 00:34:06] {3166} INFO - iteration 12, current learner rf
# [flaml.automl: 12-15
,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:27:45] {3166} INFO - iteration 188, current learner rf
# [flaml.automl: 12-15 04:27:52] {3343} INFO -  at 1316.3s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:27:52] {3166} INFO - iteration 189, current learner rf
# [flaml.automl: 12-15 04:28:02] {3343} INFO -  at 1326.7s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:28:02] {3166} INFO - iteration 190, current learner rf
# [flaml.automl: 12-15 04:28:08] {3343} INFO -  at 1332.8s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:28:08] {3166} INFO - iteration 191, current learner rf
# [flaml.automl: 12-15 04:28:21] {3343} INFO -  at 1345.8s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:28:21] {3166} INFO - iteration 192, current learner rf
# [flaml.automl: 12-15 04:28:32] {3343} INFO -  at 1356.3s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:28:32] {3166} INFO - iteration 193, current learner rf
# [flaml.automl: 12-15 04:28:39] {3343} INFO -  at 1363.5s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:28:39] {3166} INFO - iteration 194, current learner rf
# [flaml.automl: 12-15 04:28:50] {3343} INFO -  at 1374.8s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:28:50] {3166} INFO - iteration 195, current learner rf
# [flaml.automl: 12-15 04:28:56] {3343} INFO -  at 1381.0s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:28:56] {3166} INFO - iteration 196, current learner rf
# [flaml.automl: 12-15 04:29:04] {3343} INFO -  at 1388.6s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:29:04] {3166} INFO - iteration 197, current learner rf
# [flaml.automl: 12-15 04:29:11] {3343} INFO -  at 1395.6s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:29:11] {3166} INFO - iteration 198, current learner rf
# [flaml.automl: 12-15 04:29:16] {3343} INFO -  at 1400.4s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:29:16] {3166} INFO - iteration 199, current learner rf
# [flaml.automl: 12-15 04:29:25] {3343} INFO -  at 1410.0s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:29:25] {3166} INFO - iteration 200, current learner rf
# [flaml.automl: 12-15 04:29:31] {3343} INFO -  at 1415.2s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:29:31] {3166} INFO - iteration 201, current learner rf
# [flaml.automl: 12-15 04:29:41] {3343} INFO -  at 1426.1s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:29:41] {3166} INFO - iteration 202, current learner rf
# [flaml.automl: 12-15 04:29:50] {3343} INFO -  at 1434.6s,	estimator rf's best error=119.0405,	best estimator rf's best error=119.0405
# [flaml.automl: 12-15 04:29:52] {3602} INFO - retrain rf for 2.3s
# [flaml.automl: 12-15 04:29:52] {3609} INFO - retrained model: RandomForestRegressor(max_features=0.5495236489129532, max_leaf_nodes=677,
#                       n_estimators=59, n_jobs=-1)
# [flaml.automl: 12-15 04:29:52] {2901} INFO - fit succeeded
# [flaml.automl: 12-15 04:29:52] {2902} INFO - Time taken to find the best model: 997.3021621704102
# 0.93 0.86 0.3

# %% [markdown]
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 180,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
#
# Pred=[]
# rmse=[]
# model=[]
# for i in range(20):
#     X_Train, X_Test, y_Train, y_Test =train_test_split(X_train,y_train,test_size = 0.2,shuffle=True)
#     # Train with labeled input data
#     automl.fit(X_train=X_Train.drop(['Lab1'], axis=1), y_train=y_Train,**automl_settings,estimator_list=["xgboost"])
#     pred=automl.predict(X_test.drop(['Lab1'], axis=1))
#     R2=round(sm.r2_score(y_test, pred), 2)
#     r=round(np.corrcoef(y_test, pred)[0, 1],2)
#     RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),5)
#     print(r,R2,RMSE)
#     # Predict
#     #print(automl.predict(X_test))
#     # Print the best model
#     print(automl.model.estimator)
#     Pred.append(pred)
#     rmse.append(RMSE)
#     model.append(automl.model.estimator)
#
# Sorted_pred=[]
# sort_index = np.argsort(rmse)
# for i in sort_index:
#     Sorted_pred.append(Pred[i])
# ind=[i for i in range(len(y_test))]
# import matplotlib.pyplot as plt
# fig= plt.figure(figsize=(7,5))
# plt.plot(ind[:200],y_test[:200], color='blue',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[1][:200],color='salmon',linewidth=1.5)
# plt.plot(ind[:200],Sorted_pred[17][:200],color='teal',linewidth=1.5)
# plt.legend(['Actual','p10','p90'],loc = 2, bbox_to_anchor = (0.75,1), fontsize=12)
# #plt.plot(ind[:200],Sorted_pred[4][:200],color='black',linewidth=0.2)
# #plt.fill_between(np.array(ind[:200]), np.array(Sorted_pred[0][:200]), np.array(Sorted_pred[4][:200]),
#                  #color='blue', alpha=0.15)
# #plt.plot(ind,Pred[2],color='darkgoldenrod')
# #plt.plot(ind,Pred[3],color='magenta')
# #plt.plot(ind,Pred[4],color='purple')
# plt.xlabel('Observation number',fontsize=16)
# plt.ylabel('Concentraton (ppb)',fontsize=16)
# plt.title('CO-XGBoost',fontsize=16)
# plt.savefig("co_xgboost.pdf", format="pdf", bbox_inches="tight")

# %%
from flaml import AutoML
from sklearn.datasets import fetch_california_housing

# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 21600,  # in seconds
    "metric": 'rmse',
    "task": 'regression',
    "log_file_name": "california.log",
}
# Train with labeled input data
automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])#,estimator_list=["xgboost"]
pred=automl.predict(X_test.drop(['Lab1'], axis=1))
R2=round(sm.r2_score(y_test, pred), 2)
r=round(np.corrcoef(y_test, pred)[0, 1],2)
RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
print(r,R2,RMSE)
# Predict
#print(automl.predict(X_test))
# Print the best model
print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# from flaml.model import SKLearnEstimator

# %% [markdown]
# from flaml.model import SKLearnEstimator
# # SKLearnEstimator is derived from BaseEstimator
# import numpy as np
#
# class RandomForestRegressor(SKLearnEstimator):
#     def __init__(self, task="binary", **config):
#         super().__init__(task, **config)
#
#         if task in CLASSIFICATION:
#             from sklearn.ensemble import RandomForestClassifier
#
#             self.estimator_class =RandomForestClassifier
#         else:
#             from sklearn.ensemble import RandomForestRegressor
#
#             self.estimator_class =RandomForestRegressor
#
#     @classmethod
#     def search_space(cls, data_size, task):
#         space = {
#             "n_estimators": {
#                 "domain": {"domain": tune.loguniform(lower=100, upper=20000)},
#                 "low_cost_init_value": 100,
#             },
#             "max_features": {
#                 "domain": tune.loguniform(lower=0.1, upper=1),
#                 "low_cost_init_value": 0.1,
#             },
#             "max_leaf_nodes": {
#                 "domain": tune.lograndint(lower=100, upper=2500),
#                 "low_cost_init_value": 100,},
#             "min_samples_split": {"domain": tune.lograndint(lower=1, upper=20),
#             "init_value": 20,},
#
#             "min_samples_leaf": {
#                 "domain": tune.lograndint(lower=1, upper=20),
#                 "init_value": 20,
#             },
#         }
#         return space

# %% [markdown]
# from flaml import AutoML
# from flaml import tune
# automl = AutoML()
# automl.add_learner("rfr",RandomForestRegressor )

# %% [markdown]
# automl_settings = {
#     "time_budget": 1000,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["rfr"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)

# %% [markdown]
# #  NO2 DATA

# %%
X=NO2_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_O3']]#'Ref_O3'
y=NO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
#len(X_test)
X.shape
# Out:
# (3778, 8)

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # O3 DATA

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#,'Ref_CO','Ref_NO2','Ref_SO2'
X=O3_Data[['Net Signal','Lab1','Temp','RH','Month','Day_of_week','Hour','Ref_NO2']]#,'Ref_NO2'
y=O3_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)
# Out:
# 3534

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab1'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab1'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab1'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)

# %% [markdown]
# # SO2 DATA

# %%
import pandas as pd
Ref=pd.read_csv('Ref.csv')
Ref["CO"] = 1000 * Ref["CO"]
Ref['Date'] = pd.to_datetime(Ref['Date_Time'])
Ref=Ref.set_index('Date')
Ref.drop('Date_Time',axis = 1, inplace = True)
Ref=Ref.resample('5min').mean()
Ref=Ref[76463:137376]
Ref_CO=Ref['CO'].to_list()
Ref_NO2=Ref['NO2'].to_list()
Ref_SO2=Ref['SO2'].to_list()
Ref_O3=Ref['O3'].to_list()

# %%
import pandas as pd
import scipy.io
import numpy as np
data = pd.read_csv('Conc_SO2.txt', header = None,low_memory=False)
data.columns=['Lab2','Temp','RH','Time','Ref']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_so2=data
#signal=np.array(WE)-np.array(AE)
#Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data=SO2_Data.resample('5min').mean()
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna() 
data = pd.read_csv('SO2.txt', header = None,low_memory=False)
data.columns=['WE','AE','Temp','RH','Time']
Time=data['Time'].to_list()
time=[]
for i in range(len(Time)):
    time.append(float(abs(Time[i])))
Time=np.array(time)
Date=pd.to_datetime(Time-719529,unit='d').round('s')
data['Date'] = Date.tolist()
data=data.set_index('Date')
data.drop('Time',axis = 1, inplace = True)
data=data.resample('5min').mean()
Data_SO2=data
Data_SO2['Ref']=Ref_SO2
WE=Data_SO2['WE'].to_list()
AE=Data_SO2['AE'].to_list()
signal=np.array(WE)-np.array(AE)
Data_SO2['Lab2']=Data_so2['Lab2'].to_list()
Data_SO2['Net Signal']=signal
Data_SO2['Month']=Data_SO2.index.month
Data_SO2['Day_of_week']=Data_SO2.index.dayofweek
Data_SO2['Day']=Data_SO2.index.day
Data_SO2['Hour']=Data_SO2.index.hour
SO2_Data=Data_SO2
SO2_Data.shape
# Out:
# (60913, 11)

# %%
SO2_Data=SO2_Data[(SO2_Data[SO2_Data.columns] >= 0).all(axis=1)]
SO2_Data=SO2_Data.dropna()
SO2_Data=SO2_Data.resample('h').mean()
SO2_Data=SO2_Data.dropna()
SO2_Data.head()
# Out:
#                              WE          AE       Temp         RH       Ref  \
# Date
# 2019-10-10 04:00:00  344.013811  342.484305  18.332589  82.373211  1.190555
# 2019-10-10 05:00:00  347.947204  342.688948  18.160512  83.041499  1.517400
# 2019-10-10 06:00:00  349.586425  342.643169  18.294731  80.755815  1.596648
# 2019-10-10 07:00:00  348.280332  342.545156  21.874264  74.161148  1.518688
# 2019-10-10 08:00:00  352.303813  345.041354  29.141688  59.611152  1.379748
#
#                           Lab2  Net Signal  Month  Day_of_week   Day  Hour
# Date
# 2019-10-10 04:00:00   9.990807    1.529506   10.0          3.0  10.0   4.0
# 2019-10-10 05:00:00  21.173371    5.258256   10.0          3.0  10.0   5.0
# 2019-10-10 06:00:00  26.255508    6.943256   10.0          3.0  10.0   6.0
# 2019-10-10 07:00:00  22.449829    5.735176   10.0          3.0  10.0   7.0
# 2019-10-10 08:00:00  23.209242    7.262459   10.0          3.0  10.0   8.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics as sm
import matplotlib.pyplot as plt
#'Ref_CO','Ref_NO2','Ref_O3',
X=SO2_Data[['Net Signal','Lab2','Temp','RH','Month','Day_of_week','Hour']]
y=SO2_Data['Ref']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
len(X)
# Out:
# 1996

# %% [markdown]
# from flaml import AutoML
# from sklearn.datasets import fetch_california_housing
#
# # Initialize an AutoML instance
# automl = AutoML()
# # Specify automl goal and constraint
# automl_settings = {
#     "time_budget": 200,  # in seconds
#     "metric": 'rmse',
#     "task": 'regression',
#     "log_file_name": "california.log",
# }
# # Train with labeled input data
# automl.fit(X_train=X_train.drop(['Lab2'], axis=1), y_train=y_train,**automl_settings,estimator_list=["xgboost"])
# pred=automl.predict(X_test.drop(['Lab2'], axis=1))
# R2=round(sm.r2_score(y_test, pred), 2)
# r=round(np.corrcoef(y_test, pred)[0, 1],2)
# RMSE=round(np.sqrt(sm.mean_squared_error(y_test, pred))/np.mean(y),2)
# print(r,R2,RMSE)
# # Predict
# #print(automl.predict(X_test))
# # Print the best model
# print(automl.model.estimator)

# %% [markdown]
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
#
# # defining parameter range
# param_grid = {'C': [0.1, 1, 10, 100, 1000],
#               'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#               'kernel':  ['rbf', 'poly', 'sigmoid']}
#
# grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3)
#
# # fitting the model for grid search
# grid.fit(X_train.drop(['Lab2'], axis=1), y_train)
#
# # print best parameter after tuning
# print(grid.best_params_)
#
# # print how our model looks after hyper-parameter tuning
# print(grid.best_estimator_)
